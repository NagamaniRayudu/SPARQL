# %% [markdown]
# ### This notebook will illustrate on how to access DBPedia using SPARQLWrapper

# %% [markdown]
# ### Import SPARQLWrapper and Pandas

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd

# %% [markdown]
# #### The function will fetch all the values for which Mumbai is an instance of and converts the result into json and further into dataframe

# %%
def access_dbpedia_data():
    '''
    Function to make a call to DBPedia. set the Dbpedia sparql endpoint and query.
    Query to retrieve all the categories to which Mumbai (place) is instance of
    '''
    sparql = SPARQLWrapper("https://dbpedia.org/sparql")
    sparql.setQuery("""
                    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
                    PREFIX dbr: <http://dbpedia.org/resource/>
        
                    SELECT ?item
                    WHERE 
                    {
                        <http://dbpedia.org/resource/Mumbai> rdf:type ?item.
                    }  
                  """)
    sparql.setReturnFormat(JSON)
    result = sparql.query().convert()
    results_df = pd.io.json.json_normalize(result['results']['bindings'])
    return results_df

# %%
results = access_dbpedia_data()
results
# Out:
#    item.type                                         item.value
# 0        uri                http://www.w3.org/2002/07/owl#Thing
# 1        uri                  http://dbpedia.org/ontology/Place
# 2        uri               http://dbpedia.org/ontology/Location
# 3        uri             http://www.wikidata.org/entity/Q486972
# 4        uri                http://www.wikidata.org/entity/Q515
# 5        uri                   http://dbpedia.org/ontology/City
# 6        uri         http://dbpedia.org/ontology/PopulatedPlace
# 7        uri             http://dbpedia.org/ontology/Settlement
# 8        uri  http://www.w3.org/2003/01/geo/wgs84_pos#Spatia...
# 9        uri                             http://schema.org/City
# 10       uri                            http://schema.org/Place
# 11       uri  http://umbel.org/umbel/rc/Location_Underspecified
# 12       uri           http://umbel.org/umbel/rc/PopulatedPlace
# 13       uri  http://dbpedia.org/class/yago/WikicatIndianCap...
# 14       uri  http://dbpedia.org/class/yago/WikicatSchoolsIn...
# 15       uri  http://dbpedia.org/class/yago/Abstraction10000...
# 16       uri  http://dbpedia.org/class/yago/AdministrativeDi...
# 17       uri        http://dbpedia.org/class/yago/City108524735
# 18       uri    http://dbpedia.org/class/yago/District108552138
# 19       uri  http://dbpedia.org/class/yago/EducationalInsti...
# 20       uri  http://dbpedia.org/class/yago/GeographicPoint1...
# 21       uri  http://dbpedia.org/class/yago/GeographicalArea...
# 22       uri       http://dbpedia.org/class/yago/Group100031264
# 23       uri  http://dbpedia.org/class/yago/Institution10805...
# 24       uri    http://dbpedia.org/class/yago/Location100027167
# 25       uri  http://dbpedia.org/class/yago/Municipality1086...
# 26       uri      http://dbpedia.org/class/yago/Object100002684
# 27       uri  http://dbpedia.org/class/yago/Organization1080...
# 28       uri  http://dbpedia.org/class/yago/PhysicalEntity10...
# 29       uri       http://dbpedia.org/class/yago/Point108620061
# 30       uri        http://dbpedia.org/class/yago/Port108633957
# 31       uri      http://dbpedia.org/class/yago/Region108630985
# 32       uri      http://dbpedia.org/class/yago/School108276720
# 33       uri        http://dbpedia.org/class/yago/Site108651247
# 34       uri  http://dbpedia.org/class/yago/SocialGroup10795...
# 35       uri       http://dbpedia.org/class/yago/Tract108673395
# 36       uri   http://dbpedia.org/class/yago/UrbanArea108675967
# 37       uri        http://dbpedia.org/class/yago/YagoGeoEntity
# 38       uri       http://dbpedia.org/class/yago/YagoLegalActor
# 39       uri    http://dbpedia.org/class/yago/YagoLegalActorGeo
# 40       uri  http://dbpedia.org/class/yago/YagoPermanentlyL...
# 41       uri  http://dbpedia.org/class/yago/WikicatCitiesAnd...
# 42       uri  http://dbpedia.org/class/yago/WikicatCitiesWit...
# 43       uri  http://dbpedia.org/class/yago/WikicatMetropoli...
# 44       uri  http://dbpedia.org/class/yago/WikicatPopulated...
# 45       uri    http://dbpedia.org/class/yago/WikicatPortCities
# 46       uri  http://dbpedia.org/class/yago/WikicatPortCitie...
# 47       uri  http://dbpedia.org/class/yago/WikicatPortCitie...
# 48       uri  http://dbpedia.org/class/yago/WikicatPortsAndH...

# %%
results['item.value'].values
# Out:
# array(['http://www.w3.org/2002/07/owl#Thing',
#        'http://dbpedia.org/ontology/Place',
#        'http://dbpedia.org/ontology/Location',
#        'http://www.wikidata.org/entity/Q486972',
#        'http://www.wikidata.org/entity/Q515',
#        'http://dbpedia.org/ontology/City',
#        'http://dbpedia.org/ontology/PopulatedPlace',
#        'http://dbpedia.org/ontology/Settlement',
#        'http://www.w3.org/2003/01/geo/wgs84_pos#SpatialThing',
#        'http://schema.org/City', 'http://schema.org/Place',
#        'http://umbel.org/umbel/rc/Location_Underspecified',
#        'http://umbel.org/umbel/rc/PopulatedPlace',
#        'http://dbpedia.org/class/yago/WikicatIndianCapitalCities',
#        'http://dbpedia.org/class/yago/WikicatSchoolsInMumbai',
#        'http://dbpedia.org/class/yago/Abstraction100002137',
#        'http://dbpedia.org/class/yago/AdministrativeDistrict108491826',
#        'http://dbpedia.org/class/yago/City108524735',
#        'http://dbpedia.org/class/yago/District108552138',
#        'http://dbpedia.org/class/yago/EducationalInstitution108276342',
#        'http://dbpedia.org/class/yago/GeographicPoint108578706',
#        'http://dbpedia.org/class/yago/GeographicalArea108574314',
#        'http://dbpedia.org/class/yago/Group100031264',
#        'http://dbpedia.org/class/yago/Institution108053576',
#        'http://dbpedia.org/class/yago/Location100027167',
#        'http://dbpedia.org/class/yago/Municipality108626283',
#        'http://dbpedia.org/class/yago/Object100002684',
#        'http://dbpedia.org/class/yago/Organization108008335',
#        'http://dbpedia.org/class/yago/PhysicalEntity100001930',
#        'http://dbpedia.org/class/yago/Point108620061',
#        'http://dbpedia.org/class/yago/Port108633957',
#        'http://dbpedia.org/class/yago/Region108630985',
#        'http://dbpedia.org/class/yago/School108276720',
#        'http://dbpedia.org/class/yago/Site108651247',
#        'http://dbpedia.org/class/yago/SocialGroup107950920',
#        'http://dbpedia.org/class/yago/Tract108673395',
#        'http://dbpedia.org/class/yago/UrbanArea108675967',
#        'http://dbpedia.org/class/yago/YagoGeoEntity',
#        'http://dbpedia.org/class/yago/YagoLegalActor',
#        'http://dbpedia.org/class/yago/YagoLegalActorGeo',
#        'http://dbpedia.org/class/yago/YagoPermanentlyLocatedEntity',
#        'http://dbpedia.org/class/yago/WikicatCitiesAndTownsInMaharashtra',
#        'http://dbpedia.org/class/yago/WikicatCitiesWithMillionsOfInhabitants',
#        'http://dbpedia.org/class/yago/WikicatMetropolitanCitiesInIndia',
#        'http://dbpedia.org/class/yago/WikicatPopulatedCoastalPlacesInIndia',
#        'http://dbpedia.org/class/yago/WikicatPortCities',
#        'http://dbpedia.org/class/yago/WikicatPortCitiesAndTownsOfTheArabianSea',
#        'http://dbpedia.org/class/yago/WikicatPortCitiesInIndia',
#        'http://dbpedia.org/class/yago/WikicatPortsAndHarboursOfIndia'],
#       dtype=object)

# %% [markdown]
# #### This function will show how to parameterize the SPARQL Query. This function will take name as input and set it to SPARQL query. It will also how to filter the query results.

# %%
def parameterized_sparql(name):
    '''
    Function to make a call to dbpedia. set the dbpedia sparql endpoint and query.
    Query to filter only the categories from dbpedia.org url
    '''
    sparql = SPARQLWrapper("https://dbpedia.org/sparql")
    sparql.setQuery("""
                    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
                    PREFIX dbr: <http://dbpedia.org/resource/>
        
                    SELECT ?item
                    WHERE 
                    {
                        dbr:"""+name+""" rdf:type ?item.
                        filter regex(?item, "dbpedia.org")
                    }  
                  """)
    sparql.setReturnFormat(JSON)
    result = sparql.query().convert()
    results_df = pd.io.json.json_normalize(result['results']['bindings'])
    return results_df

# %%
results = parameterized_sparql("Mumbai")
results
# Out:
#    item.type                                         item.value
# 0        uri                  http://dbpedia.org/ontology/Place
# 1        uri               http://dbpedia.org/ontology/Location
# 2        uri                   http://dbpedia.org/ontology/City
# 3        uri         http://dbpedia.org/ontology/PopulatedPlace
# 4        uri             http://dbpedia.org/ontology/Settlement
# 5        uri  http://dbpedia.org/class/yago/WikicatIndianCap...
# 6        uri  http://dbpedia.org/class/yago/WikicatSchoolsIn...
# 7        uri  http://dbpedia.org/class/yago/Abstraction10000...
# 8        uri  http://dbpedia.org/class/yago/AdministrativeDi...
# 9        uri        http://dbpedia.org/class/yago/City108524735
# 10       uri    http://dbpedia.org/class/yago/District108552138
# 11       uri  http://dbpedia.org/class/yago/EducationalInsti...
# 12       uri  http://dbpedia.org/class/yago/GeographicPoint1...
# 13       uri  http://dbpedia.org/class/yago/GeographicalArea...
# 14       uri       http://dbpedia.org/class/yago/Group100031264
# 15       uri  http://dbpedia.org/class/yago/Institution10805...
# 16       uri    http://dbpedia.org/class/yago/Location100027167
# 17       uri  http://dbpedia.org/class/yago/Municipality1086...
# 18       uri      http://dbpedia.org/class/yago/Object100002684
# 19       uri  http://dbpedia.org/class/yago/Organization1080...
# 20       uri  http://dbpedia.org/class/yago/PhysicalEntity10...
# 21       uri       http://dbpedia.org/class/yago/Point108620061
# 22       uri        http://dbpedia.org/class/yago/Port108633957
# 23       uri      http://dbpedia.org/class/yago/Region108630985
# 24       uri      http://dbpedia.org/class/yago/School108276720
# 25       uri        http://dbpedia.org/class/yago/Site108651247
# 26       uri  http://dbpedia.org/class/yago/SocialGroup10795...
# 27       uri       http://dbpedia.org/class/yago/Tract108673395
# 28       uri   http://dbpedia.org/class/yago/UrbanArea108675967
# 29       uri        http://dbpedia.org/class/yago/YagoGeoEntity
# 30       uri       http://dbpedia.org/class/yago/YagoLegalActor
# 31       uri    http://dbpedia.org/class/yago/YagoLegalActorGeo
# 32       uri  http://dbpedia.org/class/yago/YagoPermanentlyL...
# 33       uri  http://dbpedia.org/class/yago/WikicatCitiesAnd...
# 34       uri  http://dbpedia.org/class/yago/WikicatCitiesWit...
# 35       uri  http://dbpedia.org/class/yago/WikicatMetropoli...
# 36       uri  http://dbpedia.org/class/yago/WikicatPopulated...
# 37       uri    http://dbpedia.org/class/yago/WikicatPortCities
# 38       uri  http://dbpedia.org/class/yago/WikicatPortCitie...
# 39       uri  http://dbpedia.org/class/yago/WikicatPortCitie...
# 40       uri  http://dbpedia.org/class/yago/WikicatPortsAndH...

# %%
results['item.value'].values
# Out:
# array(['http://dbpedia.org/ontology/Place',
#        'http://dbpedia.org/ontology/Location',
#        'http://dbpedia.org/ontology/City',
#        'http://dbpedia.org/ontology/PopulatedPlace',
#        'http://dbpedia.org/ontology/Settlement',
#        'http://dbpedia.org/class/yago/WikicatIndianCapitalCities',
#        'http://dbpedia.org/class/yago/WikicatSchoolsInMumbai',
#        'http://dbpedia.org/class/yago/Abstraction100002137',
#        'http://dbpedia.org/class/yago/AdministrativeDistrict108491826',
#        'http://dbpedia.org/class/yago/City108524735',
#        'http://dbpedia.org/class/yago/District108552138',
#        'http://dbpedia.org/class/yago/EducationalInstitution108276342',
#        'http://dbpedia.org/class/yago/GeographicPoint108578706',
#        'http://dbpedia.org/class/yago/GeographicalArea108574314',
#        'http://dbpedia.org/class/yago/Group100031264',
#        'http://dbpedia.org/class/yago/Institution108053576',
#        'http://dbpedia.org/class/yago/Location100027167',
#        'http://dbpedia.org/class/yago/Municipality108626283',
#        'http://dbpedia.org/class/yago/Object100002684',
#        'http://dbpedia.org/class/yago/Organization108008335',
#        'http://dbpedia.org/class/yago/PhysicalEntity100001930',
#        'http://dbpedia.org/class/yago/Point108620061',
#        'http://dbpedia.org/class/yago/Port108633957',
#        'http://dbpedia.org/class/yago/Region108630985',
#        'http://dbpedia.org/class/yago/School108276720',
#        'http://dbpedia.org/class/yago/Site108651247',
#        'http://dbpedia.org/class/yago/SocialGroup107950920',
#        'http://dbpedia.org/class/yago/Tract108673395',
#        'http://dbpedia.org/class/yago/UrbanArea108675967',
#        'http://dbpedia.org/class/yago/YagoGeoEntity',
#        'http://dbpedia.org/class/yago/YagoLegalActor',
#        'http://dbpedia.org/class/yago/YagoLegalActorGeo',
#        'http://dbpedia.org/class/yago/YagoPermanentlyLocatedEntity',
#        'http://dbpedia.org/class/yago/WikicatCitiesAndTownsInMaharashtra',
#        'http://dbpedia.org/class/yago/WikicatCitiesWithMillionsOfInhabitants',
#        'http://dbpedia.org/class/yago/WikicatMetropolitanCitiesInIndia',
#        'http://dbpedia.org/class/yago/WikicatPopulatedCoastalPlacesInIndia',
#        'http://dbpedia.org/class/yago/WikicatPortCities',
#        'http://dbpedia.org/class/yago/WikicatPortCitiesAndTownsOfTheArabianSea',
#        'http://dbpedia.org/class/yago/WikicatPortCitiesInIndia',
#        'http://dbpedia.org/class/yago/WikicatPortsAndHarboursOfIndia'],
#       dtype=object)
